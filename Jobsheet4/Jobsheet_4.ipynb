# %%
# Kelas Induk
class Kendaraan:
    def __init__(self, merk):
        self.merk = merk

    def mulai_mesin(self):
        print(f"Mesin kendaraan {self.merk} dinyalakan.")

# Kelas Anak (mewarisi dari Kendaraan)
class Mobil(Kendaraan):
    def __init__(self, merk, warna):
        # Memanggil __init__ kelas induk (akan dibahas di Praktikum 2)
        # Untuk sekarang, kita set merk secara manual
        self.merk = merk # Mewarisi 'merk' tapi di-set ulang di sini
        self.warna = warna # Atribut khusus Mobil

    def info_mobil(self):
        print(f"Ini adalah mobil {self.merk} berwarna {self.warna}.")

# --- Kode Utama ---
if __name__ == "__main__":
    mobil_tesla = Mobil("Tesla Model S", "Merah")

    # Memanggil metode dari kelas anak
    mobil_tesla.info_mobil()

    # Memanggil metode yang diwarisi dari kelas induk
    mobil_tesla.mulai_mesin()

    # Mengakses atribut yang diwarisi (dan di-set di anak)
    print(f"Merk mobil: {mobil_tesla.merk}")
# Out:
# Ini adalah mobil Tesla Model S berwarna Merah.
# Mesin kendaraan Tesla Model S dinyalakan.
# Merk mobil: Tesla Model S

# %% [markdown]
# #Praktikum 2

# %%
# Kelas Induk
class Person:
    def __init__(self, nama, usia):
        self.nama = nama
        self.usia = usia

    def perkenalkan_diri(self):
        print(f"Halo, nama saya {self.nama}, usia saya {self.usia} tahun.")

# Kelas Anak (mewarisi dari Person)
class Student(Person):
    def __init__(self, nama, usia, student_id, jurusan):
        # Memanggil __init__ dari kelas Person untuk inisialisasi nama dan usia
        super().__init__(nama, usia)
        # Menambahkan atribut khusus Student
        self.student_id = student_id
        self.jurusan = jurusan

    def info_akademik(self):
        print(f"ID Mahasiswa: {self.student_id}")
        print(f"Jurusan: {self.jurusan}")

    # Override perkenalkan_diri untuk menambahkan info student
    def perkenalkan_diri(self):
        super().perkenalkan_diri() # Panggil versi Person
        print(f"Saya adalah mahasiswa dengan ID {self.student_id}, jurusan {self.jurusan}.")

# --- Kode Utama ---
if __name__ == "__main__":
    # Membuat objek Person
    dosen = Person("Pak Anton", 45)
    print("-" * 20)
    dosen.perkenalkan_diri()
    print("\n" + "=" * 30 + "\n")

    # Membuat objek Student
    mahasiswa = Student("Dewi", 20, "MHS001", "Teknik Komputer")
    print("-" * 20)
    mahasiswa.perkenalkan_diri() # Panggil versi override di Student
    print("-" * 20)
    mahasiswa.info_akademik() # Panggil metode khusus Student

    # Cek atribut yang diwarisi
    print(f"\nUsia mahasiswa {mahasiswa.nama}: {mahasiswa.usia}") # usia diwarisi dari Person
# Out:
# --------------------
# Halo, nama saya Pak Anton, usia saya 45 tahun.
#
# ...
#
# --------------------
# Halo, nama saya Dewi, usia saya 20 tahun.
# Saya adalah mahasiswa dengan ID MHS001, jurusan Teknik Komputer.
# --------------------
# ID Mahasiswa: MHS001
# Jurusan: Teknik Komputer
#
# Usia mahasiswa Dewi: 20

# %% [markdown]
# #Praltikum 3

# %%
# Kelas Induk
class Hewan:
    def __init__(self, nama):
        self.nama = nama

    def bersuara(self):
        print(f"{self.nama} mengeluarkan suara generik.")

    def tampilkan_info(self):
        print(f"Ini adalah hewan bernama {self.nama}.")

# Kelas Anak
class Kucing(Hewan):
    def __init__(self, nama, ras):
        super().__init__(nama) # Panggil init induk
        self.ras = ras

    # Method Overriding untuk bersuara
    def bersuara(self):
        print(f"{self.nama} (Kucing) mengeong: Meow!")

    # Method Overriding untuk tampilkan_info, memanggil versi induk
    def tampilkan_info(self):
        super().tampilkan_info() # Panggil implementasi dari Hewan
        print(f"Ini adalah kucing ras {self.ras}.") # Tambahkan info spesifik

# --- Kode Utama ---
if __name__ == "__main__":
    hewan_umum = Hewan("Makhluk")
    kucing_persia = Kucing("Puspus", "Persia")

    print("Info Hewan Umum:")
    hewan_umum.tampilkan_info()
    hewan_umum.bersuara()
    print("-" * 20)

    print("Info Kucing Persia:")
    kucing_persia.tampilkan_info() # Akan memanggil versi Kucing
    kucing_persia.bersuara() # Akan memanggil versi Kucing
# Out:
# Info Hewan Umum:
# Ini adalah hewan bernama Makhluk.
# Makhluk mengeluarkan suara generik.
# --------------------
# Info Kucing Persia:
# Ini adalah hewan bernama Puspus.
# Ini adalah kucing ras Persia.
# Puspus (Kucing) mengeong: Meow!

# %% [markdown]
# #Praktikum 4

# %%
# Kelas Induk Level 1
class Organisme:
    def __init__(self, nama):
        self.nama = nama
        print(f"Organisme '{self.nama}' diciptakan.")

    def bernapas(self):
        print(f"{self.nama} sedang bernapas.")

# Kelas Anak Level 1 (mewarisi dari Organisme)
class Hewan(Organisme):
    def __init__(self, nama, jenis_makanan):
        super().__init__(nama) # Panggil init Organisme
        self.jenis_makanan = jenis_makanan
        print(f"Hewan '{self.nama}' adalah {self.jenis_makanan}.")

    def bergerak(self):
        print(f"{self.nama} sedang bergerak.")

# Kelas Anak Level 2 (mewarisi dari Hewan)
class Mamalia(Hewan):
    def __init__(self, nama, jenis_makanan, jumlah_kaki):
        super().__init__(nama, jenis_makanan) # Panggil init Hewan
        self.jumlah_kaki = jumlah_kaki
        print(f"Mamalia '{self.nama}' memiliki {self.jumlah_kaki} kaki.")

    def menyusui(self):
        print(f"{self.nama} sedang menyusui.")

# --- Kode Utama ---
if __name__ == "__main__":
    kucing = Mamalia("Kucing Persia", "Karnivora", 4)
    print("-" * 20)

    # Memanggil metode dari kelas Mamalia
    kucing.menyusui()

    # Memanggil metode yang diwarisi dari kelas Hewan
    kucing.bergerak()
    print(f"Jenis makanan: {kucing.jenis_makanan}")

    # Memanggil metode yang diwarisi dari kelas Organisme
    kucing.bernapas()
    print(f"Nama organisme: {kucing.nama}")
# Out:
# Organisme 'Kucing Persia' diciptakan.
# Hewan 'Kucing Persia' adalah Karnivora.
# Mamalia 'Kucing Persia' memiliki 4 kaki.
# --------------------
# Kucing Persia sedang menyusui.
# Kucing Persia sedang bergerak.
# Jenis makanan: Karnivora
# Kucing Persia sedang bernapas.
# Nama organisme: Kucing Persia

# %% [markdown]
# #Praktikum 5

# %%
import locale

# Set locale ke Indonesia untuk format mata uang
try:
    locale.setlocale(locale.LC_ALL, 'id_ID.UTF-8')
except locale.Error:
    print("Locale id_ID.UTF-8 tidak tersedia, menggunakan locale default.")

# Fungsi helper untuk format mata uang
def format_rupiah(angka):
    # Menggunakan f-string untuk format mata uang secara manual
    # Menghilangkan dependency pada locale.currency yang bisa error
    return f"Rp {angka:,.0f}".replace(',', '.') # Format dengan pemisah ribuan titik

# Kelas Induk
class Pegawai:
    def __init__(self, nama, id_pegawai, gaji_pokok):
        self.nama = nama
        self.id_pegawai = id_pegawai
        self.gaji_pokok = gaji_pokok

    def hitung_gaji(self):
        # Gaji dasar, bisa di-override
        return self.gaji_pokok

    def tampilkan_info(self):
        print(f"ID: {self.id_pegawai}, Nama: {self.nama}")
        print(f" Gaji Pokok: {format_rupiah(self.gaji_pokok)}")

# Kelas Anak 1
class Manager(Pegawai):
    def __init__(self, nama, id_pegawai, gaji_pokok, tunjangan_jabatan):
        super().__init__(nama, id_pegawai, gaji_pokok)
        self.tunjangan_jabatan = tunjangan_jabatan

    # Override hitung_gaji
    def hitung_gaji(self):
        gaji_total = super().hitung_gaji() + self.tunjangan_jabatan
        return gaji_total

    # Override tampilkan_info (memanggil versi induk)
    def tampilkan_info(self):
        print("--- Info Manager ---")
        super().tampilkan_info() # Panggil info dasar dari Pegawai
        print(f" Tunjangan Jabatan: {format_rupiah(self.tunjangan_jabatan)}")
        print(f" Total Gaji: {format_rupiah(self.hitung_gaji())}")

# Kelas Anak 2
class StafTeknis(Pegawai):
    def __init__(self, nama, id_pegawai, gaji_pokok, keahlian, bonus_keahlian):
        super().__init__(nama, id_pegawai, gaji_pokok)
        self.keahlian = keahlian
        self.bonus_keahlian = bonus_keahlian

    # Override hitung_gaji
    def hitung_gaji(self):
        gaji_total = super().hitung_gaji() + self.bonus_keahlian
        return gaji_total

    # Override tampilkan_info (memanggil versi induk)
    def tampilkan_info(self):
        print("--- Info Staf Teknis ---")
        super().tampilkan_info() # Panggil info dasar dari Pegawai
        print(f" Keahlian: {self.keahlian}")
        print(f" Bonus Keahlian: {format_rupiah(self.bonus_keahlian)}")
        print(f" Total Gaji: {format_rupiah(self.hitung_gaji())}")


# --- Kode Utama ---
if __name__ == "__main__":
    manager1 = Manager("Budi Santoso", "M001", 10000000, 5000000)
    staf1 = StafTeknis("Citra Lestari", "S001", 7000000, "Python Programming", 1500000)
    pegawai_baru = Pegawai("Rian", "P005", 5000000) # Pegawai biasa

    print("Menampilkan Informasi Pegawai:")
    manager1.tampilkan_info()
    print("-" * 30)
    staf1.tampilkan_info()
    print("-" * 30)

    print("--- Info Pegawai Baru ---")
    pegawai_baru.tampilkan_info()
    print(f" Total Gaji: {format_rupiah(pegawai_baru.hitung_gaji())}") # Memanggil versi Pegawai
    print("-" * 30)
# Out:
# Locale id_ID.UTF-8 tidak tersedia, menggunakan locale default.
# Menampilkan Informasi Pegawai:
# --- Info Manager ---
# ID: M001, Nama: Budi Santoso
#  Gaji Pokok: Rp 10.000.000
#  Tunjangan Jabatan: Rp 5.000.000
#  Total Gaji: Rp 15.000.000
# ------------------------------
# --- Info Staf Teknis ---
# ID: S001, Nama: Citra Lestari
#  Gaji Pokok: Rp 7.000.000
#  Keahlian: Python Programming
#  Bonus Keahlian: Rp 1.500.000
#  Total Gaji: Rp 8.500.000
# ------------------------------
# --- Info Pegawai Baru ---
# ID: P005, Nama: Rian
#  Gaji Pokok: Rp 5.000.000
#  Total Gaji: Rp 5.000.000
# ------------------------------

# %% [markdown]
# #Praktikum 6

# %%
class BentukGeometri:
    def __init__(self, nama_bentuk):
        self.nama = nama_bentuk
    def tampilkan_nama(self):
        print(f"Ini adalah bentuk: {self.nama}")
    def hitung_luas(self):
        print(f"Luas {self.nama} tidak dapat dihitung (generik).")

class PersegiPanjang(BentukGeometri):
    def __init__(self, panjang, lebar):
        super().__init__("Persegi Panjang")
        self.panjang = panjang
        self.lebar = lebar
    def hitung_luas(self):
        luas = self.panjang * self.lebar
        print(f"Luas {self.nama}: {luas}")

class Segitiga(BentukGeometri):
    def __init__(self, alas, tinggi):
        super().__init__("Segitiga")
        self.alas = alas
        self.tinggi = tinggi
    def hitung_luas(self):
        luas = 0.5 * self.alas * self.tinggi
        print(f"Luas {self.nama}: {luas}")

def proses_bentuk(bentuk):
    print(f"\nMemproses objek: {type(bentuk)}")

    if isinstance(bentuk, BentukGeometri):
        bentuk.tampilkan_nama()
        print("Objek ini adalah instance dari BentukGeometri (atau turunannya).")

    if isinstance(bentuk, PersegiPanjang):
        print("-> Objek ini juga instance dari PersegiPanjang.")
    elif isinstance(bentuk, Segitiga):
        print("-> Objek ini juga instance dari Segitiga.")
    else:
        # This else branch handles objects that are BentukGeometri but not PersegiPanjang or Segitiga
        # and also non-BentukGeometri objects (if the first 'if' was false).
        # The original logic had 'Objek ini BUKAN instance dari BentukGeometri.' here,
        # which was misleading if the object *was* BentukGeometri but not a specific subclass.
        # Re-evaluating the logic for clarity:
        if not isinstance(bentuk, PersegiPanjang) and not isinstance(bentuk, Segitiga) and isinstance(bentuk, BentukGeometri):
            print("-> Objek ini adalah BentukGeometri generik.")
        elif not isinstance(bentuk, BentukGeometri):
            print("Objek ini BUKAN instance dari BentukGeometri.")

    if isinstance(bentuk, str):
        print("Objek ini adalah string.")

# --- Kode Utama ---
if __name__ == "__main__":
    pp = PersegiPanjang(4, 3)
    seg = Segitiga(5, 2)
    bg = BentukGeometri("Lingkaran") # Contoh lain
    teks = "Ini string"

    daftar_objek = [pp, seg, bg, teks]

    for obj in daftar_objek:
        proses_bentuk(obj)
# Out:
# Memproses objek: <class '__main__.PersegiPanjang'>
# Ini adalah bentuk: Persegi Panjang
# Objek ini adalah instance dari BentukGeometri (atau turunannya).
# -> Objek ini juga instance dari PersegiPanjang.
#
# Memproses objek: <class '__main__.Segitiga'>
# Ini adalah bentuk: Segitiga
# Objek ini adalah instance dari BentukGeometri (atau turunannya).
# -> Objek ini juga instance dari Segitiga.
#
# Memproses objek: <class '__main__.BentukGeometri'>
# Ini adalah bentuk: Lingkaran
# Objek ini adalah instance dari BentukGeometri (atau turunannya).
# -> Objek ini adalah BentukGeometri generik.
#
# Memproses objek: <class 'str'>
# Objek ini BUKAN instance dari BentukGeometri.
# Objek ini adalah string.

# %% [markdown]
# #Praktikum 6 tetapi menghapus <class '__main__.Segitiga'>

# %%
class BentukGeometri:
    def __init__(self, nama_bentuk):
        self.nama = nama_bentuk
    def tampilkan_nama(self):
        print(f"Ini adalah bentuk: {self.nama}")
    def hitung_luas(self):
        print(f"Luas {self.nama} tidak dapat dihitung (generik).")

class PersegiPanjang(BentukGeometri):
    def __init__(self, panjang, lebar):
        super().__init__("Persegi Panjang")
        self.panjang = panjang
        self.lebar = lebar
    def hitung_luas(self):
        luas = self.panjang * self.lebar
        print(f"Luas {self.nama}: {luas}")

class Segitiga(BentukGeometri):
    def __init__(self, alas, tinggi):
        super().__init__("Segitiga")
        self.alas = alas
        self.tinggi = tinggi
    def hitung_luas(self):
        luas = 0.5 * self.alas * self.tinggi
        print(f"Luas {self.nama}: {luas}")

def proses_bentuk(bentuk):
    # print(f"\nMemproses objek: {type(bentuk)}") # Dihapus sesuai permintaan pengguna

    if isinstance(bentuk, BentukGeometri):
        bentuk.tampilkan_nama()
        print("Objek ini adalah instance dari BentukGeometri (atau turunannya).")

    if isinstance(bentuk, PersegiPanjang):
        print("-> Objek ini juga instance dari PersegiPanjang.")
    elif isinstance(bentuk, Segitiga):
        print("-> Objek ini juga instance dari Segitiga.")
    else:
        # This else branch handles objects that are BentukGeometri but not PersegiPanjang or Segitiga
        # and also non-BentukGeometri objects (if the first 'if' was false).
        # The original logic had 'Objek ini BUKAN instance dari BentukGeometri.' here,
        # which was misleading if the object *was* BentukGeometri but not a specific subclass.
        # Re-evaluating the logic for clarity:
        if not isinstance(bentuk, PersegiPanjang) and not isinstance(bentuk, Segitiga) and isinstance(bentuk, BentukGeometri):
            print("-> Objek ini adalah BentukGeometri generik.")
        elif not isinstance(bentuk, BentukGeometri):
            print("Objek ini BUKAN instance dari BentukGeometri.")

    if isinstance(bentuk, str):
        print("Objek ini adalah string.")

# --- Kode Utama ---
if __name__ == "__main__":
    pp = PersegiPanjang(4, 3)
    seg = Segitiga(5, 2)
    bg = BentukGeometri("Lingkaran") # Contoh lain
    teks = "Ini string"

    daftar_objek = [pp, seg, bg, teks]

    for obj in daftar_objek:
        proses_bentuk(obj)
# Out:
# Ini adalah bentuk: Persegi Panjang
# Objek ini adalah instance dari BentukGeometri (atau turunannya).
# -> Objek ini juga instance dari PersegiPanjang.
# Ini adalah bentuk: Segitiga
# Objek ini adalah instance dari BentukGeometri (atau turunannya).
# -> Objek ini juga instance dari Segitiga.
# Ini adalah bentuk: Lingkaran
# Objek ini adalah instance dari BentukGeometri (atau turunannya).
# -> Objek ini adalah BentukGeometri generik.
# Objek ini BUKAN instance dari BentukGeometri.
# Objek ini adalah string.

# %% [markdown]
# #Penugasan

# %%
class Mahasiswa:
    def __init__(self, nama, nim, ipk):
        self.nama = nama
        self.nim = nim
        self.ipk = ipk

    def tampilkan_info(self):
        print(f"Nama: {self.nama}")
        print(f"NIM: {self.nim}")
        print(f"IPK: {self.ipk}")

    def hitung_predikat(self):
        if self.ipk >= 3.5:
            predikat = "Dengan Pujian"
        elif self.ipk >= 3.0:
            predikat = "Sangat Memuaskan"
        elif self.ipk >= 2.5:
            predikat = "Memuaskan"
        else:
            predikat = "Cukup"
        print(f"Predikat: {predikat}")

class MahasiswaSarjana(Mahasiswa):
    def __init__(self, nama, nim, ipk, semester, sks_lulus):
        # Mengambil atribut dari kelas Induk
        super().__init__(nama, nim, ipk)
        self.semester = semester
        self.sks_lulus = sks_lulus

    def tampilkan_info(self):
        super().tampilkan_info() # Panggil info dasar dari induk
        print(f"Semester: {self.semester}")
        print(f"SKS Lulus: {self.sks_lulus}")

class MahasiswaMagister(Mahasiswa):
    def __init__(self, nama, nim, ipk, judul_tesis, nama_pembimbing):
        super().__init__(nama, nim, ipk)
        self.judul_tesis = judul_tesis
        self.nama_pembimbing = nama_pembimbing

    def tampilkan_info(self):
        super().tampilkan_info()
        print(f"Judul Tesis: {self.judul_tesis}")
        print(f"Pembimbing: {self.nama_pembimbing}")

# --- Contoh Penggunaan dengan Input Pengguna ---

print("\n=== Masukkan Data Mahasiswa Sarjana ===")
nama_s1 = input("Nama Mahasiswa Sarjana: ")
nim_s1 = input("NIM Mahasiswa Sarjana: ")
ipk_s1 = float(input("IPK Mahasiswa Sarjana: "))
semester_s1 = int(input("Semester Mahasiswa Sarjana: "))
sks_lulus_s1 = int(input("SKS Lulus Mahasiswa Sarjana: "))

mhs_s1_user = MahasiswaSarjana(nama_s1, nim_s1, ipk_s1, semester_s1, sks_lulus_s1)
print("\n--- Data Mahasiswa Sarjana Anda ---")
mhs_s1_user.tampilkan_info()
mhs_s1_user.hitung_predikat()

print("\n=== Masukkan Data Mahasiswa Magister ===")
nama_s2 = input("Nama Mahasiswa Magister: ")
nim_s2 = input("NIM Mahasiswa Magister: ")
ipk_s2 = float(input("IPK Mahasiswa Magister: "))
judul_tesis_s2 = input("Judul Tesis Mahasiswa Magister: ")
nama_pembimbing_s2 = input("Nama Pembimbing Mahasiswa Magister: ")

mhs_s2_user = MahasiswaMagister(nama_s2, nim_s2, ipk_s2, judul_tesis_s2, nama_pembimbing_s2)
print("\n--- Data Mahasiswa Magister Anda ---")
mhs_s2_user.tampilkan_info()
mhs_s2_user.hitung_predikat()
# Out:
# === Masukkan Data Mahasiswa Sarjana ===
# Nama Mahasiswa Sarjana: Nazifa Citra Nurviani
# NIM Mahasiswa Sarjana: 4.33.25.2.17
# IPK Mahasiswa Sarjana: 4.00
# Semester Mahasiswa Sarjana: 7
# SKS Lulus Mahasiswa Sarjana: 224
#
# --- Data Mahasiswa Sarjana Anda ---
# Nama: Nazifa Citra Nurviani
# NIM: 4.33.25.2.17
# IPK: 4.0
# Semester: 7
# SKS Lulus: 224
# Predikat: Dengan Pujian
#
# === Masukkan Data Mahasiswa Magister ===
# Nama Mahasiswa Magister: Citra Nurviani Nazifa
# NIM Mahasiswa Magister: 4.33.25.2.17
# IPK Mahasiswa Magister: 3.99
# Judul Tesis Mahasiswa Magister: Pengenalan Teknologi pada Bidang Forensik dan Kriminologi untuk Bahan Ajar Mahasiswa Universitas Indonesia Tingkat Lanjur
# Nama Pembimbing Mahasiswa Magister: Kurnianingsih
#
# --- Data Mahasiswa Magister Anda ---
# Nama: Citra Nurviani Nazifa
# NIM: 4.33.25.2.17
# IPK: 3.99
# Judul Tesis: Pengenalan Teknologi pada Bidang Forensik dan Kriminologi untuk Bahan Ajar Mahasiswa Universitas Indonesia Tingkat Lanjur
# ...

# %% [markdown]
# UML atau Kelas Diagram
#
# ![image.png](data:image/png;base64,...)
