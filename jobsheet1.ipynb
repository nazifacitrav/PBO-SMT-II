# %% [markdown]
# <a href="https://colab.research.google.com/github/nazifacitrav/PBO-SMT-II/blob/main/jobsheet1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Jobsheet 1

# %% [markdown]
# #Pratikum 1

# %%
# 1. Number (int, float, complex)
print("\n--- Tipe Data Numerik ---")
# Integer (int)
angka_int = 10
print(f"angka_int   = {angka_int} -> {type(angka_int)}")
# Float
angka_float = 3.14
print(f"angka_float = {angka_float} -> {type(angka_float)}")
# Complex
angka_complex = 2 + 3j
print(f"angka_complex = {angka_complex} -> {type(angka_complex)}")

# 2. Boolean
print("\n--- Tipe Data Boolean ---")
is_active = True
print(f"is_active   = {is_active} -> {type(is_active)}")

# 3. String
print("\n--- Tipe Data String ---")
teks = "Hello, Python!"
print(f"teks        = \"{teks}\" -> {type(teks)}")

# 4. List
print("\n--- Tipe Data List ---")
# List adalah tipe data terurut dan dapat diubah (mutable)
daftar_angka = [1, 2, 3, 4, 5]
print(f"daftar_angka = {daftar_angka} -> {type(daftar_angka)}")

# 5. Tuple
print("\n--- Tipe Data Tuple ---")
# Tuple adalah tipe data terurut tetapi tidak dapat diubah (immutable)
koordinat = (10, 20)
print(f"koordinat   = {koordinat} -> {type(koordinat)}")

# 6. Dictionary
print("\n--- Tipe Data Dictionary ---")
# Dictionary menyimpan data dalam pasangan key-value
data_mahasiswa = {
    "nama": "Andi",
    "nim": "A11.2022.12345",
    "jurusan": "Teknik Informatika"
}
print(f"data_mahasiswa = {data_mahasiswa} -> {type(data_mahasiswa)}")

# 7. Set
print("\n--- Tipe Data Set ---")
# Set adalah tipe data yang tidak terurut, unik (tiap elemen hanya muncul 1 kali)
himpunan_angka = {1, 2, 3, 2, 1}
print(f"himpunan_angka = {himpunan_angka} -> {type(himpunan_angka)}")

# 8. Contoh penggunaan konversi tipe data
print("\n--- Contoh Konversi Tipe Data ---")
nilai_str = "100"
print(f"nilai_str = \"{nilai_str}\" -> {type(nilai_str)}")
nilai_int = int(nilai_str) # konversi string ke integer
print(f"nilai_int = {nilai_int} -> {type(nilai_int)}")
# Out:
# --- Tipe Data Numerik ---
# angka_int   = 10 -> <class 'int'>
# angka_float = 3.14 -> <class 'float'>
# angka_complex = (2+3j) -> <class 'complex'>
#
# --- Tipe Data Boolean ---
# is_active   = True -> <class 'bool'>
#
# --- Tipe Data String ---
# teks        = "Hello, Python!" -> <class 'str'>
#
# --- Tipe Data List ---
# daftar_angka = [1, 2, 3, 4, 5] -> <class 'list'>
#
# --- Tipe Data Tuple ---
# koordinat   = (10, 20) -> <class 'tuple'>
#
# --- Tipe Data Dictionary ---
# data_mahasiswa = {'nama': 'Andi', 'nim': 'A11.2022.12345', 'jurusan': 'Teknik Informatika'} -> <class 'dict'>
#
# --- Tipe Data Set ---
# himpunan_angka = {1, 2, 3} -> <class 'set'>
#
# --- Contoh Konversi Tipe Data ---
# nilai_str = "100" -> <class 'str'>
# nilai_int = 100 -> <class 'int'>

# %% [markdown]
# #Praktikum 2

# %%
# -*- coding: utf-8 -*-
# 1. Pendeklarasian Variabel
nama = "Budi"
umur = 20
tinggi = 170.5
is_student = True
print("Nama =", nama)
print("Umur =", umur)
print("Tinggi =", tinggi, "cm")
print("Mahasiswa =", is_student)
# Python tidak memerlukan deklarasi tipe data secara eksplisit.
# Tipe data variabel akan menyesuaikan nilai yang diberikan.

# 2. Operasi Aritmetika
a = 10
b = 3
penjumlahan = a + b # Tambah
pengurangan = a - b # Kurang
perkalian = a * b # Kali
pembagian = a / b # Bagi (hasil float)
pembagian_bulat = a // b # Bagi (bulat)
modulus = a % b # Sisa bagi
pangkat = a ** b # Pemangkatan
print("\nOPERASI ARITMETIKA")
print("a =", a, ", b =", b)
print("Penjumlahan =", penjumlahan)
print("Pengurangan =", pengurangan)
print("Perkalian =", perkalian)
print("Pembagian =", pembagian)
print("Pembagian Bulat =", pembagian_bulat)
print("Modulus =", modulus)
print("Pangkat =", pangkat)

# 3. Operasi Perbandingan
# Menghasilkan nilai Boolean (True/False)
lebih_besar = a > b
kurang_dari = a < b
sama_dengan = a == b
tidak_sama = a != b
lebih_besar_sama = a >= b
kurang_sama = a <= b

print("\nOPERASI PERBANDINGAN")
print("a > b =", lebih_besar)
print("a < b =", kurang_dari)
print("a == b =", sama_dengan)
print("a != b =", tidak_sama)
print("a >= b =", lebih_besar_sama)
print("a <= b =", kurang_sama)

# 4. Operasi Logika
# and, or, not

x = True
y = False

logika_and = x and y
logika_or = x or y
logika_not_x = not x

print("\nOPERASI LOGIKA")
print("x =", x, ", y =", y)
print("x and y =", logika_and)
print("x or y =", logika_or)
print("not x =", logika_not_x)

# 5. Contoh penggunaan di dalam percabangan
if a > b and b > 0:
    print("\nKondisi terpenuhi: a lebih besar dari b, dan b masih positif.")
else:
    print("\nKondisi tidak terpenuhi atau b <= 0.")
# Out:
# Nama = Budi
# Umur = 20
# Tinggi = 170.5 cm
# Mahasiswa = True
#
# OPERASI ARITMETIKA
# a = 10 , b = 3
# Penjumlahan = 13
# Pengurangan = 7
# Perkalian = 30
# Pembagian = 3.3333333333333335
# Pembagian Bulat = 3
# Modulus = 1
# Pangkat = 1000
#
# OPERASI PERBANDINGAN
# a > b = True
# a < b = False
# a == b = False
# a != b = True
# a >= b = True
# a <= b = False
#
# OPERASI LOGIKA
# x = True , y = False
# x and y = False
# x or y = True
# not x = False
#
# Kondisi terpenuhi: a lebih besar dari b, dan b masih positif.

# %% [markdown]
# #Praktikum 3

# %%
# -*- coding: utf-8 -*-

# 1. IF Sederhana
# Program hanya mengeksekusi blok jika kondisinya True

nilai = 85
print("Contoh IF Sederhana:")
if nilai > 80:
    print("Selamat! Anda lulus dengan nilai tinggi.\n")


# 2. IF-ELSE
# Jika kondisi True, eksekusi blok if; jika False, eksekusi blok else

umur = 17
print("Contoh IF-ELSE:")
if umur >= 18:
    print("Anda sudah cukup umur untuk mendapatkan SIM.")
else:
    print("Anda belum cukup umur untuk mendapatkan SIM.\n")


# 3. IF-ELIF-ELSE
# Menangani banyak kondisi secara berurutan.
# Jika ada kondisi yang terpenuhi, blok yang bersangkutan dieksekusi,
# lalu program melewati blok kondisi setelahnya.

hari = "Rabu"
print("Contoh IF-ELIF-ELSE:")
if hari == "Senin":
    print("Hari Senin - Saatnya kembali bekerja!")
elif hari == "Selasa":
    print("Hari Selasa - Jadwal rapat mingguan.")
elif hari == "Rabu":
    print("Hari Rabu - Ada diskon di beberapa toko.")
else:
    print("Hari lainnya - Atur jadwalmu dengan baik.\n")

# 4. IF Bersarang (Nested IF)
# Kondisi di dalam kondisi, biasa digunakan jika kita perlu
# memeriksa sub-kondisi setelah kondisi pertama terpenuhi.

suhu = 35
print("Contoh IF Bersarang (Nested IF):")
if suhu > 30:
    print("Cuaca cukup panas.")
    if suhu > 40:
        print("Bahkan sangat terik! Disarankan banyak minum air.")
    else:
        print("Masih relatif normal, tapi tetap jaga kesehatan.")
else:
    print("Cuaca sepertinya cukup sejuk.\n")


# 5. Menggabungkan Percabangan dengan Operasi Logika
# Memeriksa beberapa kondisi sekaligus dengan and, or, not

nilai_teori = 75
nilai_praktik = 80
print("Contoh IF dengan Operasi Logika AND/OR:")
if nilai_teori >= 70 and nilai_praktik >= 70:
    print("Anda lulus karena nilai teori dan praktik memadai.")
elif nilai_teori < 70 and nilai_praktik < 70:
    print("Anda perlu meningkatkan nilai teori dan praktik.")
elif nilai_teori < 70:
    print("Anda perlu meningkatkan nilai teori.")
else:
    print("Anda perlu meningkatkan nilai praktik.\n")


# 6. Penggunaan If Ternary (atau Conditional Expression)
# Bentuk ringkas: <hasil_if_true> if <kondisi> else <hasil_if_false>

angka = -5
print("Contoh If Ternary (Conditional Expression):")
status = "Positif" if angka > 0 else "Negatif atau Nol"
print("Angka =", angka, "=>", status)
# Out:
# Contoh IF Sederhana:
# Selamat! Anda lulus dengan nilai tinggi.
#
# Contoh IF-ELSE:
# Anda belum cukup umur untuk mendapatkan SIM.
#
# Contoh IF-ELIF-ELSE:
# Hari Rabu - Ada diskon di beberapa toko.
# Contoh IF Bersarang (Nested IF):
# Cuaca cukup panas.
# Masih relatif normal, tapi tetap jaga kesehatan.
# Contoh IF dengan Operasi Logika AND/OR:
# Anda lulus karena nilai teori dan praktik memadai.
# Contoh If Ternary (Conditional Expression):
# Angka = -5 => Negatif atau Nol

# %% [markdown]
# #Praktikum 4

# %%
# -*- coding: utf-8 -*-

# 1. FOR Loop dengan range()
print("1) FOR loop dengan range()")
for i in range(5):
    print("Perulangan ke-", i)
# range(5) menghasilkan nilai 0, 1, 2, 3, dan 4
# Sehingga perulangan akan berjalan sebanyak 5 kali

print() # pemisah output

# 2. FOR Loop untuk mengiterasi List
print("2) FOR loop mengiterasi list")
buah = ["apel", "mangga", "jeruk", "pisang"]
for item in buah:
    print("Buah:", item)
# Loop akan mengeksekusi setiap elemen dalam list "buah"

print()

# 3. WHILE Loop
print("3) WHILE loop sederhana")
count = 0
while count < 5:
    print("count =", count)
    count += 1 # increment
# Perulangan while terus dijalankan selama kondisi (count < 5) bernilai True

print()

# 4. BREAK pada Loop
print("4) BREAK di dalam loop")
for i in range(10):
    if i == 3:
        print("Loop dihentikan pada i =", i)
        break # mengakhiri loop saat i = 3
    print("i =", i)
# Keyword break langsung menghentikan keseluruhan perulangan

print()

# 5. CONTINUE pada Loop
print("5) CONTINUE di dalam loop")
for i in range(5):
    if i == 2:
        print("Lewati i =", i, "dengan continue")
        continue # melewati iterasi saat ini dan lanjut ke iterasi berikutnya
    print("i =", i)
# Saat i = 2, baris print("i =", i) tidak akan dieksekusi

print()

# 6. NESTED Loop (Loop Bersarang)
print("6) NESTED loop")
for i in range(3): # Loop luar (outer loop)
    for j in range(2): # Loop dalam (inner loop)
        print(f"i={i}, j={j}")
# Pada setiap iterasi i, loop j akan berjalan dari 0 sampai 1

print()

# 7. Memanfaatkan ELSE pada Loop
print("7) ELSE pada loop for/while")
# Python memiliki fitur unik: blok else pada loop
# Blok else akan dieksekusi jika loop selesai tanpa di-break.

for x in range(3):
    print("x =", x)
else:
    print("Loop for telah selesai tanpa break.\n")

y = 0
while y < 3:
    print("y =", y)
    y += 1
else:
    print("Loop while telah selesai tanpa break.\n")

# 8. PASS sebagai placeholder
print("8) PASS (placeholder)")
for i in range(3):
    if i == 1:
        pass # pass tidak melakukan apa-apa, digunakan sebagai placeholder
    print("i =", i)
# Out:
# 1) FOR loop dengan range()
# Perulangan ke- 0
# Perulangan ke- 1
# Perulangan ke- 2
# Perulangan ke- 3
# Perulangan ke- 4
#
# 2) FOR loop mengiterasi list
# Buah: apel
# Buah: mangga
# Buah: jeruk
# Buah: pisang
#
# 3) WHILE loop sederhana
# count = 0
# count = 1
# count = 2
# count = 3
# count = 4
#
# 4) BREAK di dalam loop
# i = 0
# i = 1
# i = 2
# Loop dihentikan pada i = 3
#
# 5) CONTINUE di dalam loop
# i = 0
# i = 1
# Lewati i = 2 dengan continue
# i = 3
# i = 4
#
# 6) NESTED loop
# i=0, j=0
# i=0, j=1
# i=1, j=0
# i=1, j=1
# i=2, j=0
# i=2, j=1
#
# 7) ELSE pada loop for/while
# x = 0
# x = 1
# x = 2
# Loop for telah selesai tanpa break.
#
# y = 0
# y = 1
# y = 2
# Loop while telah selesai tanpa break.
#
# 8) PASS (placeholder)
# i = 0
# i = 1
# i = 2

# %% [markdown]
# #Penugasan

# %%
# --- PROGRAM 1: Menghitung BMI ---

print("=== Program Kalkulator BMI ===")
# Menerima input dari pengguna (diubah ke tipe float agar bisa menerima desimal)
berat = float(input("Masukkan berat badan Anda (kg): "))
tinggi_cm = float(input("Masukkan tinggi badan Anda (cm): "))

# Mengonversi tinggi dari cm ke meter
tinggi_m = tinggi_cm / 100

# Menghitung nilai BMI
bmi = berat / (tinggi_m ** 2)

# Menentukan kategori berdasarkan nilai BMI
if bmi < 18.5:
    kategori = "Underweight"
elif 18.5 <= bmi <= 24.9:
    kategori = "Normal"
elif 25.0 <= bmi <= 29.9:
    kategori = "Overweight"
else:
    kategori = "Obese" # Tambahan jika BMI 30 ke atas

# Menampilkan hasil
print("\n--- Hasil ---")
print(f"Nilai BMI Anda : {bmi:.2f}")
print(f"Kategori       : {kategori}")
# Out:
# === Program Kalkulator BMI ===
# Masukkan berat badan Anda (kg): 100
# Masukkan tinggi badan Anda (cm): 189
#
# --- Hasil ---
# Nilai BMI Anda : 27.99
# Kategori       : Overweight

# %% [markdown]
# #PENUGASAN 2

# %%
# --- PROGRAM 2: Cek Bilangan Genap, Ganjil, dan Prima ---

print("=== Program Pengecek Bilangan ===")
# Menerima input dari pengguna (bilangan bulat/integer)
angka = int(input("Masukkan sebuah bilangan bulat: "))

# 1. Cek Genap atau Ganjil
if angka % 2 == 0:
    status_genap_ganjil = "Genap"
else:
    status_genap_ganjil = "Ganjil"

# 2. Cek Bilangan Prima
is_prima = True
# Bilangan prima harus lebih besar dari 1
if angka <= 1:
    is_prima = False
else:
    # Mengecek faktor pembagi dari 2 hingga akar kuadrat dari angka tersebut
    for i in range(2, int(angka ** 0.5) + 1):
        if angka % i == 0:
            is_prima = False
            break

status_prima = "Prima" if is_prima else "Bukan Prima"

# Menampilkan hasil
print("\n--- Hasil ---")
print(f"Angka {angka} adalah bilangan {status_genap_ganjil} dan termasuk bilangan {status_prima}.")
# Out:
# === Program Pengecek Bilangan ===
# Masukkan sebuah bilangan bulat: 20
#
# --- Hasil ---
# Angka 20 adalah bilangan Genap dan termasuk bilangan Bukan Prima.
